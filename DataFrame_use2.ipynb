# %%
import pandas as pd
from scipy import *
from pylab import *
#import requests

# %%
df=pd.read_csv("http://research.stlouisfed.org/fred2/series/UNRATE/downloaddata/UNRATE.csv",index_col=0);df
# Out:
#             VALUE
# DATE
# 1948-01-01    3.4
# 1948-02-01    3.8
# 1948-03-01    4.0
# 1948-04-01    3.9
# 1948-05-01    3.5
# 1948-06-01    3.6
# 1948-07-01    3.6
# 1948-08-01    3.9
# 1948-09-01    3.8
# 1948-10-01    3.7
# 1948-11-01    3.8
# 1948-12-01    4.0
# 1949-01-01    4.3
# 1949-02-01    4.7
# 1949-03-01    5.0
# 1949-04-01    5.3
# 1949-05-01    6.1
# 1949-06-01    6.2
# 1949-07-01    6.7
# 1949-08-01    6.8
# 1949-09-01    6.6
# 1949-10-01    7.9
# 1949-11-01    6.4
# 1949-12-01    6.6
# 1950-01-01    6.5
# 1950-02-01    6.4
# 1950-03-01    6.3
# 1950-04-01    5.8
# 1950-05-01    5.5
# 1950-06-01    5.4
# ...           ...
# 2016-04-01    5.0
# 2016-05-01    4.7
# 2016-06-01    4.9
# 2016-07-01    4.9
# 2016-08-01    4.9
# 2016-09-01    5.0
# 2016-10-01    4.9
# 2016-11-01    4.6
# 2016-12-01    4.7
# 2017-01-01    4.8
# 2017-02-01    4.7
# 2017-03-01    4.5
# 2017-04-01    4.4
# 2017-05-01    4.3
# 2017-06-01    4.3
# 2017-07-01    4.3
# 2017-08-01    4.4
# ...

# %%
df.head()
# Out:
#             VALUE
# DATE
# 1948-01-01    3.4
# 1948-02-01    3.8
# 1948-03-01    4.0
# 1948-04-01    3.9
# 1948-05-01    3.5

# %%
df['VALUE'].plot();show()
# Out:
# /usr/local/lib/python2.7/site-packages/pandas/core/indexes/base.py:2084: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return getitem(key)
