# %%
import pandas as pd
from scipy import *
from pylab import *

# %% [markdown]
# % Part 1

# %%
orders=pd.read_table("http://bit.ly/chiporders")

# %%
orders.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39

# %%
col_names=['use_id','age','gender','occupation','zip_code']
pd.read_table("http://bit.ly/movieusers",sep='|',header=None,names=col_names)
# Out:
#      use_id  age gender     occupation zip_code
# 0         1   24      M     technician    85711
# 1         2   53      F          other    94043
# 2         3   23      M         writer    32067
# 3         4   24      M     technician    43537
# 4         5   33      F          other    15213
# 5         6   42      M      executive    98101
# 6         7   57      M  administrator    91344
# 7         8   36      M  administrator    05201
# 8         9   29      M        student    01002
# 9        10   53      M         lawyer    90703
# 10       11   39      F          other    30329
# 11       12   28      F          other    06405
# 12       13   47      M       educator    29206
# 13       14   45      M      scientist    55106
# 14       15   49      F       educator    97301
# 15       16   21      M  entertainment    10309
# 16       17   30      M     programmer    06355
# 17       18   35      F          other    37212
# 18       19   40      M      librarian    02138
# ...

# %% [markdown]
# #Part 2

# %%
pd.read_csv("https://github.com/QuantEcon/QuantEcon.lectures.code/raw/master/pandas/data/test_pwt.csv")
# Out:
#          country country isocode  year          POP       XRAT         tcgdp  \
# 0      Argentina             ARG  2000    37335.653   0.999500  2.950722e+05
# 1      Australia             AUS  2000    19053.186   1.724830  5.418047e+05
# 2          India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3         Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4         Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
# 5   South Africa             ZAF  2000    45064.098   6.939830  2.272424e+05
# 6  United States             USA  2000   282171.957   1.000000  9.898700e+06
# 7        Uruguay             URY  2000     3219.793  12.099592  2.525596e+04
#
#           cc         cg
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546
# 6  72.347054   6.032454
# 7  78.978740   5.108068

# %%
df=pd.read_csv("https://github.com/QuantEcon/QuantEcon.lectures.code/raw/master/pandas/data/test_pwt.csv");df
# Out:
#          country country isocode  year          POP       XRAT         tcgdp  \
# 0      Argentina             ARG  2000    37335.653   0.999500  2.950722e+05
# 1      Australia             AUS  2000    19053.186   1.724830  5.418047e+05
# 2          India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3         Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4         Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
# 5   South Africa             ZAF  2000    45064.098   6.939830  2.272424e+05
# 6  United States             USA  2000   282171.957   1.000000  9.898700e+06
# 7        Uruguay             URY  2000     3219.793  12.099592  2.525596e+04
#
#           cc         cg
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546
# 6  72.347054   6.032454
# 7  78.978740   5.108068

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[2:5]
# Out:
#   country country isocode  year          POP       XRAT         tcgdp  \
# 2   India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3  Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4  Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
#
#           cc         cg
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954

# %%
df['year']
# Out:
# 0    2000
# 1    2000
# 2    2000
# 3    2000
# 4    2000
# 5    2000
# 6    2000
# 7    2000
# Name: year, dtype: int64

# %%
df[['country','POP']]
# Out:
#          country          POP
# 0      Argentina    37335.653
# 1      Australia    19053.186
# 2          India  1006300.297
# 3         Israel     6114.570
# 4         Malawi    11801.505
# 5   South Africa    45064.098
# 6  United States   282171.957
# 7        Uruguay     3219.793

# %%
df.size
# Out:
# 64

# %%
df.shape
# Out:
# (8, 8)

# %%
df.values
# Out:
# array([['Argentina', 'ARG', 2000, 37335.653, 0.9995, 295072.21869,
#         75.716805379, 5.578804289600001],
#        ['Australia', 'AUS', 2000, 19053.186, 1.7248299999999999,
#         541804.6521, 67.75902599300001, 6.720097533200001],
#        ['India', 'IND', 2000, 1006300.297, 44.9416, 1728144.3748,
#         64.575551328, 14.072205773],
#        ['Israel', 'ISR', 2000, 6114.57, 4.07733, 129253.89422999999,
#         64.436450847, 10.266688415],
#        ['Malawi', 'MWI', 2000, 11801.505, 59.543808333, 5026.2217836,
#         74.707624181, 11.658954494000001],
#        ['South Africa', 'ZAF', 2000, 45064.098, 6.939830000000001,
#         227242.36949, 72.718710427, 5.7265463933000005],
#        ['United States', 'USA', 2000, 282171.957, 1.0, 9898700.0,
#         72.34705430300001, 6.0324539789],
#        ['Uruguay', 'URY', 2000, 3219.7929999999997, 12.099591667,
#         25255.961693, 78.978740282, 5.108067988]], dtype=object)

# %%
df.iloc[2,5]
# Out:
# 1728144.3748000001

# %%
df.iloc[:2,:2]
# Out:
#      country country isocode
# 0  Argentina             ARG
# 1  Australia             AUS

# %%
df.loc[:2,['country','tcgdp']]
# Out:
#      country         tcgdp
# 0  Argentina  2.950722e+05
# 1  Australia  5.418047e+05
# 2      India  1.728144e+06

# %%
type(df.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df.loc[df.index[:2],['country','tcgdp']]
# Out:
#      country         tcgdp
# 0  Argentina  295072.21869
# 1  Australia  541804.65210

# %%
df=df[['country','POP','tcgdp']]
df
# Out:
#          country          POP         tcgdp
# 0      Argentina    37335.653  2.950722e+05
# 1      Australia    19053.186  5.418047e+05
# 2          India  1006300.297  1.728144e+06
# 3         Israel     6114.570  1.292539e+05
# 4         Malawi    11801.505  5.026222e+03
# 5   South Africa    45064.098  2.272424e+05
# 6  United States   282171.957  9.898700e+06
# 7        Uruguay     3219.793  2.525596e+04

# %%
df=df.set_index('country')

# %%
df.columns
# Out:
# Index([u'POP', u'tcgdp'], dtype='object')

# %%
df_newu=df.copy();
df_newu['POP']=df_newu['POP']*1000;df_newu
# Out:
#                         POP         tcgdp
# country
# Argentina      3.733565e+07  2.950722e+05
# Australia      1.905319e+07  5.418047e+05
# India          1.006300e+09  1.728144e+06
# Israel         6.114570e+06  1.292539e+05
# Malawi         1.180150e+07  5.026222e+03
# South Africa   4.506410e+07  2.272424e+05
# United States  2.821720e+08  9.898700e+06
# Uruguay        3.219793e+06  2.525596e+04

# %%
df_newu['GDP percap']=df_newu['tcgdp']*1e6/df_newu['POP']
df_newu
# Out:
#                         POP         tcgdp    GDP percap
# country
# Argentina      3.733565e+07  2.950722e+05   7903.229085
# Australia      1.905319e+07  5.418047e+05  28436.433261
# India          1.006300e+09  1.728144e+06   1717.324719
# Israel         6.114570e+06  1.292539e+05  21138.672749
# Malawi         1.180150e+07  5.026222e+03    425.896679
# South Africa   4.506410e+07  2.272424e+05   5042.647686
# United States  2.821720e+08  9.898700e+06  35080.381854
# Uruguay        3.219793e+06  2.525596e+04   7843.970620

# %%
df_newu['GDP percap'].plot(kind='bar')
show()

# %%
df_sort=df_newu.sort_values(by='GDP percap',ascending=False);df_sort
# Out:
#                         POP         tcgdp    GDP percap
# country
# United States  2.821720e+08  9.898700e+06  35080.381854
# Australia      1.905319e+07  5.418047e+05  28436.433261
# Israel         6.114570e+06  1.292539e+05  21138.672749
# Argentina      3.733565e+07  2.950722e+05   7903.229085
# Uruguay        3.219793e+06  2.525596e+04   7843.970620
# South Africa   4.506410e+07  2.272424e+05   5042.647686
# India          1.006300e+09  1.728144e+06   1717.324719
# Malawi         1.180150e+07  5.026222e+03    425.896679

# %%
df_sort['GDP percap'].plot(kind='bar');show()
